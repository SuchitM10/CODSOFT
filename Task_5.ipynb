# %% [markdown]
# <a href="https://colab.research.google.com/github/SuchitM10/CODSOFT/blob/main/Task_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task - 5 (Sept 27, 2023)
#
# CREDIT CARD FRAUD DETECTION
#
# Build a machine learning model to identify fraudulent credit card transactions.
#
# Preprocess and normalize the transaction data, handle class imbalance issues, and split the dataset into training and testing sets.
#
# Train a classification algorithm, such as logistic regression or random forests, to classify transactions as fraudulent or genuine.
#
# Evaluate the model's performance using metrics like precision, recall, and F1-score, and consider techniques like oversampling or undersampling for improving results.

# %%
#Importing necessary dependencies
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score

# %%
#loading dataset
credit_card_data = pd.read_csv("/content/creditcard.csv")

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# last 5 rows of the dataset
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 17913  29027 -0.422159  0.231118  1.666711  0.451976 -0.203598  0.097244
# 17914  29030  1.177387 -0.215585  0.202972  0.215323 -0.029312  0.601788
# 17915  29030 -0.553746  0.880858  1.644821 -0.132657  0.120940 -0.267411
# 17916  29030 -2.844632  3.717960 -7.165428  4.120419 -2.991039 -2.942326
# 17917  29031  1.050204  0.078269  0.484733  1.349623       NaN       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 17913 -0.039666  0.354218  0.062463  ...  0.110909  0.435121 -0.056658
# 17914 -0.297021  0.188082  0.436370  ... -0.055842  0.075903 -0.187120
# 17915  0.466892  0.222443 -0.639624  ... -0.133339 -0.348662  0.029947
# 17916 -4.925187  2.204337 -2.663613  ...  0.894495 -0.340246  0.012222
# 17917       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17918 entries, 0 to 17917
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    17918 non-null  int64
#  1   V1      17918 non-null  float64
#  2   V2      17918 non-null  float64
#  3   V3      17918 non-null  float64
#  4   V4      17918 non-null  float64
#  5   V5      17917 non-null  float64
#  6   V6      17917 non-null  float64
#  7   V7      17917 non-null  float64
#  8   V8      17917 non-null  float64
#  9   V9      17917 non-null  float64
#  10  V10     17917 non-null  float64
#  11  V11     17917 non-null  float64
#  12  V12     17917 non-null  float64
#  13  V13     17917 non-null  float64
#  14  V14     17917 non-null  float64
#  15  V15     17917 non-null  float64
#  16  V16     17917 non-null  float64
#  17  V17     17917 non-null  float64
#  18  V18     17917 non-null  float64
#  19  V19     17917 non-null  float64
# ...

# %%
# checking missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
#filling the missing values with null strings
credit_card_data = credit_card_data.fillna('')

# %%
# checking distribution of legitimate transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# 0.0    17836
# 1.0       81
#            1
# Name: Class, dtype: int64

# %% [markdown]
# We have a highly imbalanced dataset.
#
# 0 -> Legitimate Transactions
#
# 1 -> Fraudulent Transactions

# %%
# preparing the dataset for analysis
legitimate = credit_card_data[credit_card_data.Class == 0]
fraudulent = credit_card_data[credit_card_data.Class == 1]

# %%
print(legitimate.shape)
print(fraudulent.shape)
# Out:
# (17836, 31)
# (81, 31)

# %%
#statistical description of dataset
legitimate.Amount.describe()
# Out:
# count     17836.0
# unique     5668.0
# top           1.0
# freq        793.0
# Name: Amount, dtype: float64

# %%
fraudulent.Amount.describe()
# Out:
# count     81.0
# unique    20.0
# top        1.0
# freq      40.0
# Name: Amount, dtype: float64

# %%
# comparing the values for both transactions
credit_card_data.groupby('Class').mean(numeric_only=True)
# Out:
#                Time        V1        V2         V3        V4
# Class
# 0.0    13891.131980 -0.203851  0.228560   0.840631  0.263581
# 1.0    16833.074074 -9.315066  6.779465 -13.052870  6.451318
#        29031.000000  1.050204  0.078269   0.484733  1.349623

# %% [markdown]
# Under-Sampling

# %%
#creating sample dataset containing similar distribution of legitimate transactions and Fraudulent Transactions
legitimate_sample = legitimate.sample(n=81)

# %%
#concatenating two datasets
concat_dataset = pd.concat([legitimate_sample, fraudulent], axis=0)

# %%
concat_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 13428  23755  1.109985  0.368032 -0.061407  1.376844  0.070437 -1.100573
# 11829  20308 -0.168686  0.850077  1.361096  1.122372  0.699974 -0.008313
# 2721    2265 -1.062820  1.267781  0.751608 -0.142661 -0.035006  0.178435
# 111       73  1.148187  0.085837  0.120702  1.126665  0.214711  0.537381
# 15884  27327  1.383589 -1.200015  0.721262 -1.267915 -1.787452 -0.648605
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 13428  0.610397 -0.487201  0.920589  ... -0.088583 -0.126343 -0.217999
# 11829  0.849159 -0.260636  0.596964  ...  0.043858  0.717953 -0.068458
# 2721  -0.003398   0.86766 -0.421917  ... -0.161987 -0.498819  0.105064
# 111   -0.049989  0.186175  0.111781  ... -0.091112 -0.095475  -0.16675
# 15884 -1.171974 -0.021242 -1.613697  ... -0.198882 -0.275279  0.153579
#
#             V24       V25       V26       V27       V28 Amount Class
# ...

# %%
concat_dataset.tail()
# Out:
#         Time         V1         V2         V3        V4         V5        V6  \
# 17317  28625 -27.848181  15.598193 -28.923756  6.418442 -20.346228 -4.828202
# 17366  28658 -28.524268  15.876923 -29.468732  6.447591    -20.786 -4.865613
# 17407  28692 -29.200329  16.155701 -30.013712  6.476731  -21.22581 -4.902997
# 17453  28726 -29.876366  16.434525 -30.558697  6.505862 -21.665654 -4.940356
# 17480  28755 -30.552380  16.713389 -31.103685  6.534984 -22.105532 -4.977692
#
#               V7         V8        V9  ...       V21       V22       V23  \
# 17317 -19.210896  18.329406 -3.668735  ...  1.802149 -2.062934 -1.269843
# 17366 -19.501084  18.748872  -3.64299  ...   1.80577 -2.119376  -1.31745
# 17407 -19.791248  19.168327 -3.617242  ...  1.809371 -2.175815 -1.365104
# 17453 -20.081391  19.587773 -3.591491  ...  1.812954 -2.232252 -1.412803
# 17480 -20.371514  20.007208 -3.565738  ...   1.81652 -2.288686 -1.460544
#
# ...

# %%
concat_dataset.groupby('Class').mean(numeric_only= True)
# Out:
#                Time        V1        V2         V3        V4
# Class
# 0.0    13185.234568 -0.158360  0.292631   0.919365  0.555830
# 1.0    16833.074074 -9.315066  6.779465 -13.052870  6.451318

# %%
#splitting the dataset into features and columns
X = concat_dataset.drop(columns='Class', axis=1)
Y = concat_dataset['Class']

# %%
print(X)
# Out:
#         Time         V1         V2         V3        V4         V5        V6  \
# 13428  23755   1.109985   0.368032  -0.061407  1.376844   0.070437 -1.100573
# 11829  20308  -0.168686   0.850077   1.361096  1.122372   0.699974 -0.008313
# 2721    2265  -1.062820   1.267781   0.751608 -0.142661  -0.035006  0.178435
# 111       73   1.148187   0.085837   0.120702  1.126665   0.214711  0.537381
# 15884  27327   1.383589  -1.200015   0.721262 -1.267915  -1.787452 -0.648605
# ...      ...        ...        ...        ...       ...        ...       ...
# 17317  28625 -27.848181  15.598193 -28.923756  6.418442 -20.346228 -4.828202
# 17366  28658 -28.524268  15.876923 -29.468732  6.447591    -20.786 -4.865613
# 17407  28692 -29.200329  16.155701 -30.013712  6.476731  -21.22581 -4.902997
# 17453  28726 -29.876366  16.434525 -30.558697  6.505862 -21.665654 -4.940356
# 17480  28755 -30.552380  16.713389 -31.103685  6.534984 -22.105532 -4.977692
#
# ...

# %%
print(Y)
# Out:
# 13428    0.0
# 11829    0.0
# 2721     0.0
# 111      0.0
# 15884    0.0
#         ...
# 17317    1.0
# 17366    1.0
# 17407    1.0
# 17453    1.0
# 17480    1.0
# Name: Class, Length: 162, dtype: object

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
Y_train = Y_train.astype('int')
Y_test = Y_test.astype('int')

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (162, 30) (129, 30) (33, 30)

# %% [markdown]
# Logistic Regression Model

# %%
model = LogisticRegression(solver='lbfgs', max_iter=2000)

# %%
# training the Logistic Regression Model using training Data
model.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
# precision on training data
X_train_prediction = model.predict(X_train)
training_data_precision = precision_score(X_train_prediction, Y_train)
training_data_f1_score = f1_score(X_train_prediction, Y_train)
training_data_recall_score = recall_score(X_train_prediction, Y_train)

# %%
print('Precision on Training data : ', training_data_precision)
print('F1-score on training data: ', training_data_f1_score)
print('Recall on training data: ', training_data_recall_score)
# Out:
# Precision on Training data :  0.9846153846153847
# F1-score on training data:  0.9922480620155039
# Recall on training data:  1.0

# %%
# precision on test data
X_test_prediction = model.predict(X_test)
testing_data_precision = precision_score(X_test_prediction, Y_test)
testing_data_f1_score = f1_score(X_test_prediction, Y_test)
testing_data_recall_score = recall_score(X_test_prediction, Y_test)

# %%
print('Precision on testing data : ', testing_data_precision)
print('F1-score on testing data: ', testing_data_f1_score)
print('Recall on testing data: ', testing_data_recall_score)
# Out:
# Precision on testing data :  0.875
# F1-score on testing data:  0.875
# Recall on testing data:  0.875
